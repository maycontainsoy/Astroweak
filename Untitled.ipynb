# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
# Plot Parameters
plt.rcParams['figure.figsize']=(15,10)
plt.rcParams['font.size']=18

# %%
ratesEXP = np.loadtxt('A23Z13EXP.txt')
ratesTHR = np.loadtxt('A23Z13THR.txt')

# %%
rhoYE1EXP = ratesEXP[0:12,:]
rhoYE1THR = ratesTHR[0:12,:]

rhoYE2EXP = ratesEXP[12:24,:]
rhoYE2THR = ratesTHR[12:24,:]

rhoYE3EXP = ratesEXP[24:36,:]
rhoYE3THR = ratesTHR[24:36,:]

rhoYE4EXP = ratesEXP[36:48,:]
rhoYE4THR = ratesTHR[36:48,:]

rhoYE5EXP = ratesEXP[48:60,:]
rhoYE5THR = ratesTHR[48:60,:]

rhoYE6EXP = ratesEXP[60:72,:]
rhoYE6THR = ratesTHR[60:72,:]

rhoYE7EXP = ratesEXP[72:84,:]
rhoYE7THR = ratesTHR[72:84,:]

rhoYE8EXP = ratesEXP[84:96,:]
rhoYE8THR = ratesTHR[84:96,:]

# %%
plt.plot(np.log10(rhoYE2EXP[:,3]),'o--',label='Exp. Revised')
plt.plot(np.log10(rhoYE2THR[:,3]),'o--',label='Pure Theory')

plt.xlabel('Temperature Grid Index')
plt.ylabel('Electron Capture Production Rate')
plt.title('Density Point $10^{5}$')

plt.legend(loc=0)
plt.show()

# %%
plt.plot(rhoYE1EXP[:,1],np.log10(rhoYE1EXP[:,3]),'o--',label='Exp. Revised $\\rho Y_{e}=10^{4}$')
plt.plot(rhoYE1THR[:,1],np.log10(rhoYE1THR[:,3]),'o--',label='Pure Theory $\\rho Y_{e}=10^{4}$')

plt.plot(rhoYE2EXP[:,1],np.log10(rhoYE2EXP[:,3]),'o--',label='Exp. Revised $\\rho Y_{e}=10^{5}$')
plt.plot(rhoYE2THR[:,1],np.log10(rhoYE2THR[:,3]),'o--',label='Pure Theory $\\rho Y_{e}=10^{5}$')

plt.plot(rhoYE3EXP[:,1],np.log10(rhoYE3EXP[:,3]),'o--',label='Exp. Revised $\\rho Y_{e}=10^{6}$')
plt.plot(rhoYE3THR[:,1],np.log10(rhoYE3THR[:,3]),'o--',label='Pure Theory $\\rho Y_{e}=10^{6}$')

plt.plot(rhoYE4EXP[:,1],np.log10(rhoYE4EXP[:,3]),'o--',label='Exp. Revised $\\rho Y_{e}=10^{7}$')
plt.plot(rhoYE4THR[:,1],np.log10(rhoYE4THR[:,3]),'o--',label='Pure Theory $\\rho Y_{e}=10^{7}$')

plt.plot(rhoYE5EXP[:,1],np.log10(rhoYE5EXP[:,3]),'o--',label='Exp. Revised $\\rho Y_{e}=10^{8}$')
plt.plot(rhoYE5THR[:,1],np.log10(rhoYE5THR[:,3]),'o--',label='Pure Theory $\\rho Y_{e}=10^{8}$')

plt.plot(rhoYE6EXP[:,1],np.log10(rhoYE6EXP[:,3]),'o--',label='Exp. Revised $\\rho Y_{e}=10^{9}$')
plt.plot(rhoYE6THR[:,1],np.log10(rhoYE6THR[:,3]),'o--',label='Pure Theory $\\rho Y_{e}=10^{9}$')

plt.plot(rhoYE7EXP[:,1],np.log10(rhoYE7EXP[:,3]),'o--',label='Exp. Revised $\\rho Y_{e}=10^{10}$')
plt.plot(rhoYE7THR[:,1],np.log10(rhoYE7THR[:,3]),'o--',label='Pure Theory $\\rho Y_{e}=10^{10}$')

plt.plot(rhoYE8EXP[:,1],np.log10(rhoYE8EXP[:,3]),'o--',label='Exp. Revised $\\rho Y_{e}=10^{11}$')
plt.plot(rhoYE8THR[:,1],np.log10(rhoYE8THR[:,3]),'o--',label='Pure Theory $\\rho Y_{e}=10^{11}$')

plt.xlabel('$T_{9}$ Temperature')
plt.ylabel('$\log_{10}$ (Electron Capture Production Rate)')
#plt.title('Density Point $10^{5}$')

#plt.legend(loc=0)
plt.show()

# %%
T1exp = np.array([rhoYE1EXP[0,3],rhoYE2EXP[0,3],rhoYE3EXP[0,3],rhoYE4EXP[0,3],rhoYE5EXP[0,3],rhoYE6EXP[0,3],rhoYE7EXP[0,3],rhoYE8EXP[0,3]])
T2exp = np.array([rhoYE1EXP[1,3],rhoYE2EXP[1,3],rhoYE3EXP[1,3],rhoYE4EXP[1,3],rhoYE5EXP[1,3],rhoYE6EXP[1,3],rhoYE7EXP[1,3],rhoYE8EXP[1,3]])
T3exp = np.array([rhoYE1EXP[2,3],rhoYE2EXP[2,3],rhoYE3EXP[2,3],rhoYE4EXP[2,3],rhoYE5EXP[2,3],rhoYE6EXP[2,3],rhoYE7EXP[2,3],rhoYE8EXP[2,3]])
T4exp = np.array([rhoYE1EXP[3,3],rhoYE2EXP[3,3],rhoYE3EXP[3,3],rhoYE4EXP[3,3],rhoYE5EXP[3,3],rhoYE6EXP[3,3],rhoYE7EXP[3,3],rhoYE8EXP[3,3]])
T5exp = np.array([rhoYE1EXP[4,3],rhoYE2EXP[4,3],rhoYE3EXP[4,3],rhoYE4EXP[4,3],rhoYE5EXP[4,3],rhoYE6EXP[4,3],rhoYE7EXP[4,3],rhoYE8EXP[4,3]])
T6exp = np.array([rhoYE1EXP[5,3],rhoYE2EXP[5,3],rhoYE3EXP[5,3],rhoYE4EXP[5,3],rhoYE5EXP[5,3],rhoYE6EXP[5,3],rhoYE7EXP[5,3],rhoYE8EXP[5,3]])
T7exp = np.array([rhoYE1EXP[6,3],rhoYE2EXP[6,3],rhoYE3EXP[6,3],rhoYE4EXP[6,3],rhoYE5EXP[6,3],rhoYE6EXP[6,3],rhoYE7EXP[6,3],rhoYE8EXP[6,3]])
T8exp = np.array([rhoYE1EXP[7,3],rhoYE2EXP[7,3],rhoYE3EXP[7,3],rhoYE4EXP[7,3],rhoYE5EXP[7,3],rhoYE6EXP[7,3],rhoYE7EXP[7,3],rhoYE8EXP[7,3]])

T1thr = np.array([rhoYE1THR[0,3],rhoYE2THR[0,3],rhoYE3THR[0,3],rhoYE4THR[0,3],rhoYE5THR[0,3],rhoYE6THR[0,3],rhoYE7THR[0,3],rhoYE8EXP[0,3]])
T2thr = np.array([rhoYE1THR[1,3],rhoYE2THR[1,3],rhoYE3THR[1,3],rhoYE4THR[1,3],rhoYE5THR[1,3],rhoYE6THR[1,3],rhoYE7THR[1,3],rhoYE8EXP[1,3]])
T3thr = np.array([rhoYE1THR[2,3],rhoYE2THR[2,3],rhoYE3THR[2,3],rhoYE4THR[2,3],rhoYE5THR[2,3],rhoYE6THR[2,3],rhoYE7THR[2,3],rhoYE8EXP[2,3]])
T4thr = np.array([rhoYE1THR[3,3],rhoYE2THR[3,3],rhoYE3THR[3,3],rhoYE4THR[3,3],rhoYE5THR[3,3],rhoYE6THR[3,3],rhoYE7THR[3,3],rhoYE8EXP[3,3]])
T5thr = np.array([rhoYE1THR[4,3],rhoYE2THR[4,3],rhoYE3THR[4,3],rhoYE4THR[4,3],rhoYE5THR[4,3],rhoYE6THR[4,3],rhoYE7THR[4,3],rhoYE8EXP[4,3]])
T6thr = np.array([rhoYE1THR[5,3],rhoYE2THR[5,3],rhoYE3THR[5,3],rhoYE4THR[5,3],rhoYE5THR[5,3],rhoYE6THR[5,3],rhoYE7THR[5,3],rhoYE8EXP[5,3]])
T7thr = np.array([rhoYE1THR[6,3],rhoYE2THR[6,3],rhoYE3THR[6,3],rhoYE4THR[6,3],rhoYE5THR[6,3],rhoYE6THR[6,3],rhoYE7THR[6,3],rhoYE8EXP[6,3]])
T8thr = np.array([rhoYE1THR[7,3],rhoYE2THR[7,3],rhoYE3THR[7,3],rhoYE4THR[7,3],rhoYE5THR[7,3],rhoYE6THR[7,3],rhoYE7THR[7,3],rhoYE8EXP[7,3]])

densityGrid = [10**4,10**5,10**6,10**7,10**8,10**9,10**10,10**11]

# %%
plt.plot(np.log10(densityGrid),np.log10(T1exp),'o--')#,label='Revised Exp.')
plt.plot(np.log10(densityGrid),np.log10(T2exp),'o--')
plt.plot(np.log10(densityGrid),np.log10(T3exp),'o--')
plt.plot(np.log10(densityGrid),np.log10(T4exp),'o--')
plt.plot(np.log10(densityGrid),np.log10(T5exp),'o--')
plt.plot(np.log10(densityGrid),np.log10(T6exp),'o--')
plt.plot(np.log10(densityGrid),np.log10(T7exp),'o--')
plt.plot(np.log10(densityGrid),np.log10(T8exp),'o--')

plt.plot(np.log10(densityGrid),np.log10(T1thr),'o--',label='$\\rho Y_{e}=10^{4}$')
plt.plot(np.log10(densityGrid),np.log10(T2thr),'o--',label='$\\rho Y_{e}=10^{5}$')
plt.plot(np.log10(densityGrid),np.log10(T3thr),'o--',label='$\\rho Y_{e}=10^{6}$')
plt.plot(np.log10(densityGrid),np.log10(T4thr),'o--',label='$\\rho Y_{e}=10^{7}$')
plt.plot(np.log10(densityGrid),np.log10(T5thr),'o--',label='$\\rho Y_{e}=10^{8}$')
plt.plot(np.log10(densityGrid),np.log10(T6thr),'o--',label='$\\rho Y_{e}=10^{9}$')
plt.plot(np.log10(densityGrid),np.log10(T7thr),'o--',label='$\\rho Y_{e}=10^{10}$')
plt.plot(np.log10(densityGrid),np.log10(T8thr),'o--',label='$\\rho Y_{e}=10^{11}$')

plt.xlabel('$\log_{10}(T_{9})$')
plt.ylabel('$\log_{10}$(Electron Capture Production Rate)')
plt.title('Aluminum-23 Electron Capture Rate')

plt.legend(loc=0)
plt.show()

# %%
f,(ax1,ax2)=plt.subplots(2,sharex=True,sharey=False)
ax1.plot(np.log10(densityGrid),np.log10(T8exp),'o--',label='Revised Exp.')
ax1.plot(np.log10(densityGrid),np.log10(T8thr),'o--',label='Pure Theory')
ax1.set_title('Aluminum-23 Electron Capture Rate for $\\rho Y_{e}=10^{11}$')
ax1.set_ylabel('$\log_{10}$(Electron Capture Rate)')

ax2.plot(np.log10(densityGrid),np.abs(T8exp-T8thr),'o--')
ax2.set_xlabel('$\log_{10}(T_{9})$')
ax2.set_ylabel('$\log_{10}$ Abs. Difference')

f.subplots_adjust(hspace=0)
