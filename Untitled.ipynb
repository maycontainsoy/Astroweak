# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
# Plot Parameters
plt.rcParams['figure.figsize']=(15,10)
plt.rcParams['font.size']=18

# %%
ratesEXP = np.loadtxt('P28_RE.txt')
ratesTHR = np.loadtxt('P28_PT.txt')

# %%
rhoYE1EXP = ratesEXP[0:12,:]
rhoYE1THR = ratesTHR[0:12,:]

rhoYE2EXP = ratesEXP[12:24,:]
rhoYE2THR = ratesTHR[12:24,:]

rhoYE3EXP = ratesEXP[24:36,:]
rhoYE3THR = ratesTHR[24:36,:]

rhoYE4EXP = ratesEXP[36:48,:]
rhoYE4THR = ratesTHR[36:48,:]

rhoYE5EXP = ratesEXP[48:60,:]
rhoYE5THR = ratesTHR[48:60,:]

rhoYE6EXP = ratesEXP[60:72,:]
rhoYE6THR = ratesTHR[60:72,:]

rhoYE7EXP = ratesEXP[72:84,:]
rhoYE7THR = ratesTHR[72:84,:]

rhoYE8EXP = ratesEXP[84:96,:]
rhoYE8THR = ratesTHR[84:96,:]

# %%
colIndx=3

plt.plot(rhoYE1EXP[:,1],np.log10(rhoYE1EXP[:,colIndx]),'o--')#,label='Exp. Revised $\\rho Y_{e}=10^{4}$')
plt.plot(rhoYE1THR[:,1],np.log10(rhoYE1THR[:,colIndx]),'x--',label='Pure Theory $\\rho Y_{e}=10^{4}$')

plt.plot(rhoYE2EXP[:,1],np.log10(rhoYE2EXP[:,colIndx]),'o--')#,label='Exp. Revised $\\rho Y_{e}=10^{5}$')
plt.plot(rhoYE2THR[:,1],np.log10(rhoYE2THR[:,colIndx]),'x--',label='Pure Theory $\\rho Y_{e}=10^{5}$')

plt.plot(rhoYE3EXP[:,1],np.log10(rhoYE3EXP[:,colIndx]),'o--')#,label='Exp. Revised $\\rho Y_{e}=10^{6}$')
plt.plot(rhoYE3THR[:,1],np.log10(rhoYE3THR[:,colIndx]),'x--',label='Pure Theory $\\rho Y_{e}=10^{6}$')

plt.plot(rhoYE4EXP[:,1],np.log10(rhoYE4EXP[:,colIndx]),'o--')#,label='Exp. Revised $\\rho Y_{e}=10^{7}$')
plt.plot(rhoYE4THR[:,1],np.log10(rhoYE4THR[:,colIndx]),'x--',label='Pure Theory $\\rho Y_{e}=10^{7}$')

plt.plot(rhoYE5EXP[:,1],np.log10(rhoYE5EXP[:,colIndx]),'o--')#,label='Exp. Revised $\\rho Y_{e}=10^{8}$')
plt.plot(rhoYE5THR[:,1],np.log10(rhoYE5THR[:,colIndx]),'x--',label='Pure Theory $\\rho Y_{e}=10^{8}$')

plt.plot(rhoYE6EXP[:,1],np.log10(rhoYE6EXP[:,colIndx]),'o--')#,label='Exp. Revised $\\rho Y_{e}=10^{9}$')
plt.plot(rhoYE6THR[:,1],np.log10(rhoYE6THR[:,colIndx]),'x--',label='Pure Theory $\\rho Y_{e}=10^{9}$')

plt.plot(rhoYE7EXP[:,1],np.log10(rhoYE7EXP[:,colIndx]),'o--')#,label='Exp. Revised $\\rho Y_{e}=10^{10}$')
plt.plot(rhoYE7THR[:,1],np.log10(rhoYE7THR[:,colIndx]),'x--',label='Pure Theory $\\rho Y_{e}=10^{10}$')

plt.plot(rhoYE8EXP[:,1],np.log10(rhoYE8EXP[:,colIndx]),'o--')#,label='Exp. Revised $\\rho Y_{e}=10^{11}$')
plt.plot(rhoYE8THR[:,1],np.log10(rhoYE8THR[:,colIndx]),'x--',label='Pure Theory $\\rho Y_{e}=10^{11}$')

plt.xlabel('$T_{9}$ Temperature')
plt.ylabel('$\log_{10}$ (Electron Capture Production Rate)')
plt.title('$^{28}$P Pure Theory vs. Revised Experiment (default parameters)')

plt.legend(loc=0)
plt.show()

# %%
T1exp = np.array([rhoYE1EXP[0,colIndx],rhoYE2EXP[0,colIndx],rhoYE3EXP[0,colIndx],rhoYE4EXP[0,colIndx],rhoYE5EXP[0,colIndx],rhoYE6EXP[0,colIndx],rhoYE7EXP[0,colIndx],rhoYE8EXP[0,colIndx]])
T2exp = np.array([rhoYE1EXP[1,colIndx],rhoYE2EXP[1,colIndx],rhoYE3EXP[1,colIndx],rhoYE4EXP[1,colIndx],rhoYE5EXP[1,colIndx],rhoYE6EXP[1,colIndx],rhoYE7EXP[1,colIndx],rhoYE8EXP[1,colIndx]])
T3exp = np.array([rhoYE1EXP[2,colIndx],rhoYE2EXP[2,colIndx],rhoYE3EXP[2,colIndx],rhoYE4EXP[2,colIndx],rhoYE5EXP[2,colIndx],rhoYE6EXP[2,colIndx],rhoYE7EXP[2,colIndx],rhoYE8EXP[2,colIndx]])
T4exp = np.array([rhoYE1EXP[3,colIndx],rhoYE2EXP[3,colIndx],rhoYE3EXP[3,colIndx],rhoYE4EXP[3,colIndx],rhoYE5EXP[3,colIndx],rhoYE6EXP[3,colIndx],rhoYE7EXP[3,colIndx],rhoYE8EXP[3,colIndx]])
T5exp = np.array([rhoYE1EXP[4,colIndx],rhoYE2EXP[4,colIndx],rhoYE3EXP[4,colIndx],rhoYE4EXP[4,colIndx],rhoYE5EXP[4,colIndx],rhoYE6EXP[4,colIndx],rhoYE7EXP[4,colIndx],rhoYE8EXP[4,colIndx]])
T6exp = np.array([rhoYE1EXP[5,colIndx],rhoYE2EXP[5,colIndx],rhoYE3EXP[5,colIndx],rhoYE4EXP[5,colIndx],rhoYE5EXP[5,colIndx],rhoYE6EXP[5,colIndx],rhoYE7EXP[5,colIndx],rhoYE8EXP[5,colIndx]])
T7exp = np.array([rhoYE1EXP[6,colIndx],rhoYE2EXP[6,colIndx],rhoYE3EXP[6,colIndx],rhoYE4EXP[6,colIndx],rhoYE5EXP[6,colIndx],rhoYE6EXP[6,colIndx],rhoYE7EXP[6,colIndx],rhoYE8EXP[6,colIndx]])
T8exp = np.array([rhoYE1EXP[7,colIndx],rhoYE2EXP[7,colIndx],rhoYE3EXP[7,colIndx],rhoYE4EXP[7,colIndx],rhoYE5EXP[7,colIndx],rhoYE6EXP[7,colIndx],rhoYE7EXP[7,colIndx],rhoYE8EXP[7,colIndx]])

T1thr = np.array([rhoYE1THR[0,colIndx],rhoYE2THR[0,colIndx],rhoYE3THR[0,colIndx],rhoYE4THR[0,colIndx],rhoYE5THR[0,colIndx],rhoYE6THR[0,colIndx],rhoYE7THR[0,colIndx],rhoYE8EXP[0,colIndx]])
T2thr = np.array([rhoYE1THR[1,colIndx],rhoYE2THR[1,colIndx],rhoYE3THR[1,colIndx],rhoYE4THR[1,colIndx],rhoYE5THR[1,colIndx],rhoYE6THR[1,colIndx],rhoYE7THR[1,colIndx],rhoYE8EXP[1,colIndx]])
T3thr = np.array([rhoYE1THR[2,colIndx],rhoYE2THR[2,colIndx],rhoYE3THR[2,colIndx],rhoYE4THR[2,colIndx],rhoYE5THR[2,colIndx],rhoYE6THR[2,colIndx],rhoYE7THR[2,colIndx],rhoYE8EXP[2,colIndx]])
T4thr = np.array([rhoYE1THR[3,colIndx],rhoYE2THR[3,colIndx],rhoYE3THR[3,colIndx],rhoYE4THR[3,colIndx],rhoYE5THR[3,colIndx],rhoYE6THR[3,colIndx],rhoYE7THR[3,colIndx],rhoYE8EXP[3,colIndx]])
T5thr = np.array([rhoYE1THR[4,colIndx],rhoYE2THR[4,colIndx],rhoYE3THR[4,colIndx],rhoYE4THR[4,colIndx],rhoYE5THR[4,colIndx],rhoYE6THR[4,colIndx],rhoYE7THR[4,colIndx],rhoYE8EXP[4,colIndx]])
T6thr = np.array([rhoYE1THR[5,colIndx],rhoYE2THR[5,colIndx],rhoYE3THR[5,colIndx],rhoYE4THR[5,colIndx],rhoYE5THR[5,colIndx],rhoYE6THR[5,colIndx],rhoYE7THR[5,colIndx],rhoYE8EXP[5,colIndx]])
T7thr = np.array([rhoYE1THR[6,colIndx],rhoYE2THR[6,colIndx],rhoYE3THR[6,colIndx],rhoYE4THR[6,colIndx],rhoYE5THR[6,colIndx],rhoYE6THR[6,colIndx],rhoYE7THR[6,colIndx],rhoYE8EXP[6,colIndx]])
T8thr = np.array([rhoYE1THR[7,colIndx],rhoYE2THR[7,colIndx],rhoYE3THR[7,colIndx],rhoYE4THR[7,colIndx],rhoYE5THR[7,colIndx],rhoYE6THR[7,colIndx],rhoYE7THR[7,colIndx],rhoYE8EXP[7,colIndx]])

densityGrid = [10**4,10**5,10**6,10**7,10**8,10**9,10**10,10**11]

# %%
plt.plot(np.log10(densityGrid),np.log10(T1exp),'o--')#,label='Revised Exp.')
plt.plot(np.log10(densityGrid),np.log10(T2exp),'o--')
plt.plot(np.log10(densityGrid),np.log10(T3exp),'o--')
plt.plot(np.log10(densityGrid),np.log10(T4exp),'o--')
plt.plot(np.log10(densityGrid),np.log10(T5exp),'o--')
plt.plot(np.log10(densityGrid),np.log10(T6exp),'o--')
plt.plot(np.log10(densityGrid),np.log10(T7exp),'o--')
plt.plot(np.log10(densityGrid),np.log10(T8exp),'o--')

plt.plot(np.log10(densityGrid),np.log10(T1thr),'x--',label='$\\rho Y_{e}=10^{4}$')
plt.plot(np.log10(densityGrid),np.log10(T2thr),'x--',label='$\\rho Y_{e}=10^{5}$')
plt.plot(np.log10(densityGrid),np.log10(T3thr),'x--',label='$\\rho Y_{e}=10^{6}$')
plt.plot(np.log10(densityGrid),np.log10(T4thr),'x--',label='$\\rho Y_{e}=10^{7}$')
plt.plot(np.log10(densityGrid),np.log10(T5thr),'x--',label='$\\rho Y_{e}=10^{8}$')
plt.plot(np.log10(densityGrid),np.log10(T6thr),'x--',label='$\\rho Y_{e}=10^{9}$')
plt.plot(np.log10(densityGrid),np.log10(T7thr),'x--',label='$\\rho Y_{e}=10^{10}$')
plt.plot(np.log10(densityGrid),np.log10(T8thr),'x--',label='$\\rho Y_{e}=10^{11}$')

plt.xlabel('$\log_{10}(T_{9})$')
plt.ylabel('$\log_{10}$(Electron Capture Production Rate)')
plt.title('$^{28}$P Electron Capture Rate Pure Theory vs. Revised Experiment ')

plt.legend(loc=0)
plt.show()

# %%
f,(ax1,ax2)=plt.subplots(2,sharex=True,sharey=False)
ax1.plot(np.log10(densityGrid),np.log10(T1exp),'o--',label='Revised Exp.')
ax1.plot(np.log10(densityGrid),np.log10(T1thr),'x--',label='Pure Theory')
ax1.set_title('$^{24}$Na Electron Capture Rate for $\\rho Y_{e}=10^{4}$')
ax1.set_ylabel('$\log_{10}$(Electron Capture Rate)')

ax2.plot(np.log10(densityGrid),np.abs(T1exp-T1thr),'o--')
ax2.set_xlabel('$\log_{10}(T_{9})$')
ax2.set_ylabel('$\log_{10}$ Abs. Difference')

ax1.legend()

f.subplots_adjust(hspace=0)
# Out:
# /home/slauber/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log10
#
# /home/slauber/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log10
#   This is separate from the ipykernel package so we can avoid doing imports until
